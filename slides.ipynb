# %% [markdown]
# # Remote Research Tools Demo
# ### Neal Fultz <<nfultz@ucla.edu>>
# ### SSC-ERT
# ### Wed, Apr 8, 2020

# %% [markdown]
# ## Setup

# %%
# Notebook config / "magic"
# %matplotlib inline

# %%
# Imports
from sklearn.datasets import load_iris
from matplotlib import pyplot as plt

# %%
# Load data set
iris = load_iris()

# %% [markdown]
# ## Plot

# %%
# The indices of the features that we are plotting
x_index = 0
y_index = 1

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Computing resources
#
# ### UCLA
#   - [Hoffman](https://idre.ucla.edu/hoffman2) - IDRE
#   - [TS2](https://ccpr.ucla.edu/services/computing/) - CCPR (Windows)
#   - [Nicco](https://computing.sscnet.ucla.edu/services/research-computing/) - SSC
#       - GPU Successor in testing
#
# ### Cloud
#   - [Amazon Web Services](https://aws.amazon.com/research-credits/)
#   - [Google Cloud](https://edu.google.com/programs/credits/research/)
#   - [IBM](https://www.ibm.com/academic)
#   - [Microsoft Azure](https://www.microsoft.com/en-us/research/academic-program/microsoft-azure-for-research/)

# %% [markdown]
# ## Other resources
#
#   - [GitHub for Educators](https://education.github.com/)
#   - [Stats 404](https://github.com/ikukuyeva/Stats-404-Statistical-Computing) <- Example of running a course through GitHub
#   - [Intro to Python @ UCLA QCB](https://qcb.ucla.edu/collaboratory-2/workshops/w9-intro-to-python/)

# %% [markdown]
# ## Consulting Resources
#
#   - [SSC DS](https://calend.ly/sscert-stats) <- This is me & Mike Tzen
#   - [IDRE Stats](https://stats.idre.ucla.edu/) / [IDRE HPC](https://idre.ucla.edu/resources/hpc/consulting)
#   - [DS Center @ YRL](https://www.library.ucla.edu/location/data-science-center) / [DataSquad](https://www.library.ucla.edu/datasquad)
#   - [Dept of Stats Consulting](http://scc.stat.ucla.edu/)

# %% [markdown]
# ## Contact Me
#
#   - <<nfultz@ucla.edu>>
#   - <https://calend.ly/sscert-stats> <- This is my calendar
#   - <https://github.com/nfultz/remote_research_2020_04> <- GH repo of this talk

# %% [markdown]
# ## Questions & Comments
